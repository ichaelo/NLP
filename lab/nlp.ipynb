# %% [markdown]
# <h2> <strong>Часть 2 - анализ текстовых данных </strong></h2>
# Провести аналитику текстовых данных.
#
# Токенезировать и лемматизировать полученные текстовые данные полученные из 1 части задания
# Токенизация - разделение слов на предложения
# Лемматизация - перевод слов в начальную форму
# Посчитать наиболее встречающиеся пары подлежащих и сказуемых
# Посчитать самые популлярные слова (исключая стоп-слова, словарь стоп слов можно найти в nltk, либо отбросить по частям речи)
# Вывести статистику (по убыванию, наиболее встречающеся пары и самые популярные слова за исключением стоп-слов)

# %%
import sqlite3
import natasha
import nltk
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import string
from pandas import DataFrame
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Potron\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# <h2>Достаём данные из базы

# %%
connection = sqlite3.connect('articles.db')
cursor = connection.cursor()
cursor.execute("""SELECT title FROM articles LIMIT 100""")
title = cursor.fetchall()
cursor.execute("""SELECT contents FROM articles LIMIT 100""")
content = cursor.fetchall()

# %% [markdown]
# <h2>Подготовка

# %%
data = dict(zip(title, content))

from natasha import (
    Segmenter,
    MorphVocab,

    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,

    PER,
    NamesExtractor,

    Doc
)

segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

# %% [markdown]
# <h2>1. Токенезировать и лемматизировать полученные текстовые данные полученные из 1 части задания

# %% [markdown]
# <h3> Синтаксис

# %%
from ipymarkup import show_dep_ascii_markup as show_markup
articles = list(data.values())
articleForSyntax = articles[0]

doc = Doc(str(articleForSyntax))
doc.segment(segmenter)
doc.parse_syntax(syntax_parser)
doc.tag_morph(morph_tagger)

for sentence in doc.sents: # получаем предложения
  sentence.syntax.print()
# Out:
# ┌────────────► (          punct
# │           ┌► '          punct
# │ ┌►┌─┌───┌─└─ Видеокарты nsubj
# │ │ │ │ ┌─└►┌─ Radeon     appos
# │ │ │ │ │   └► RX         flat:foreign
# │ │ │ │ └────► 6000       appos
# │ │ │ └──────► ,          punct
# │ │ └────────► как        case
# │ │     ┌────► мы         nsubj
# │ │     │   ┌► уже        advmod
# │ │     │ ┌►└─ сегодня    advmod
# └─└─┌─┌─└─└─── говорили
#     │ │   ┌──► ,          punct
#     │ │   │ ┌► постепенно advmod
#     │ └►┌─└─└─ исчезают   conj
#     │   │   ┌► из         case
#     │   └──►└─ продажи    obl
#     └────────► .          punct
#         ┌────► Это      nsubj
#         │   ┌► не       advmod
#         │ ┌►└─ очень    advmod
# ┌───────└─└─── хорошо
# │       │   ┌► для      case
# │       └──►└─ геймеров obl
# │ ┌──────────► ,        punct
# │ │ ┌──────►┌─ так      mark
# │ │ │       └► как      fixed
# │ │ │ ┌────►┌─ линейка  nsubj
# │ │ │ │ ┌─┌─└► Radeon   appos
# │ │ │ │ │ └──► RX       flat:foreign
# │ │ │ │ └────► 7000     appos
# │ └─└─└───┌─── включает
# │         │ ┌► меньше   nummod:gov
# │         └►└─ моделей  obj
# └────────────► .        punct
#           ┌──► Однако     advmod
#           │ ┌► хорошая    amod
# ┌────────►│ └─ новость    nsubj
# │         │ ┌► в          case
# │ ┌───────└─└─ том
# │ │ ┌────────► ,          punct
# │ │ │ ┌──────► что        mark
# │ │ │ │ ┌──►┌─ видеокарты nsubj
# │ │ │ │ │ ┌─└► RX         appos
# │ │ │ │ │ └──► 7000       appos
# │ │ │ │ │   ┌► активно    advmod
# └─└►└─└─└─┌─└─ дешевеют   acl
#           └──► .          punct
#                 ┌► Буквально  advmod
#               ┌►└─ недавно    advmod
#               │ ┌► AMD        nsubj
# ┌─────────────└─└─ снижала
# │           ┌─└──► цену       obj
# │           │   ┌► на         case
# │ ┌───────┌─└►┌─└─ RX         nmod
# │ │       │   └──► 7700       appos
# │ │       └──────► XT         flat:foreign
# │ │     ┌────────► ,          punct
# │ │     │ ┌──────► а          cc
# │ │     │ │ ┌────► сейчас     advmod
# │ │     │ │ │   ┌► эта        det
# │ │     │ │ │ ┌►└─ карта      nsubj:pass
# │ │     │ │ │ │ ┌► уже        advmod
# │ │ ┌─┌►└─└─└─└─└─ продаётся  conj
# │ │ │ │ │   │ └──► дешевле    advmod
# │ │ │ │ │   └────► .          punct
# │ │ │ │ │       ┌► \          punct
# │ └►│ │ │       │  n          punct
# │   │ │ └──────►└─ Официально advmod
# │   │ │         ┌► цена       nsubj
# │   │ └─────┌───└─ упала
# │   │       │ ┌──► до         case
# │   │       │ │ ┌► 420        nummod
# │   │       └►└─└─ долларов   obl
# │   │           ┌► в          case
# │   └──────────►└─ феврале    obl
# └────────────────► .          punct
#       ┌──────► Теперь     advmod
#       │        же
#       │     ┌► многие     amod
#       │ ┌►┌─└─ продавцы   nsubj
#       │ │ │ ┌► в          case
#       │ │ └►└─ США        nmod
# ┌─┌───└─└───┌─ предлагают
# │ │       ┌─└► карту      obj
# │ │       │ ┌► по         case
# │ │     ┌─└►└─ цене       nmod
# │ │     │ ┌──► в          case
# │ │     │ │ ┌► 400        nummod
# │ │     └►└─└─ долларов   nmod
# │ │ ┌────────► ,          punct
# │ │ │ ┌──────► и          cc
# │ │ │ │ ┌────► это        nsubj
# │ │ │ │ │ ┌──► без        case
# │ │ │ │ │ │ ┌► всяких     det
# │ └►└─└─└─└─└─ акций      obl
# └────────────► .          punct
#                               ┌──────────► А            cc
#                               │            есть
#                               │ ┌────────► предложение  nsubj:pass
#                               │ │     ┌──► и            advmod
#                 ┌────────────►│ │     │    за           case
#                 │             │ │     │ ┌► 395          nummod
#                 │   ┌────────►│ │     └─└─ долларов     conj
# ┌──────────────►│   │         │ │          .            punct
# │               │   │         │ │ ┌──────► \            punct
# │           ┌──►│   │         │ │ │        n            appos
# │           │   │   │         │ │ │     ┌► В            case
# │           │   │   │         │ │ │   ┌►└─ Европе       obl
# │           │   │   │         │ │ │   │ ┌► ситуация     nsubj
# │ ┌─┌───────│ ┌─│   │     ┌───└─└─│ ┌─└─└─ схожая
# │ │ │       │ │ │   │     │       │ │ ┌──► :            punct
# │ │ │       │ │ │   │     │       │ │ │ ┌► карта        nsubj
# │ │ │       │ │ │   │ ┌─┌─│       └─└►└─└─ стартует     parataxis
# │ │ │       │ │ │   │ │ │ │       │   ┌──► с            case
# │ │ │       │ │ │   │ │ │ │       │   │ ┌► 420          nummod
# │ │ │       │ │ │   │ │ │ │       └──►└─└─ евро         obl
# │ │ │ ┌────►│ │ │   │ │ │ │                ,            punct
# │ │ │ │ ┌──►│ │ │   │ │ │ │                но           cc
# │ │ │ │ │ ┌►│ │ │   │ │ │ │                это          nsubj
# │ │ │ │ │ │ │ │ │   │ │ │ │ ┌────────────► уже          advmod
# │ │ │ │ │ │ │ │ │   │ │ │ │ │           ┌► с            case
# │ │ │ │ │ │ │ │ │ ┌─└─│ │ └►│ ┌───────┌─└─ учётом       parataxis
# │ │ │ │ │ │ │ │ │ │   │ │   │ │       └──► налогов      nmod
# │ │ │ │ │ │ │ │ │ │   │ │   │ │   ┌──────► ,            punct
# │ │ │ │ │ │ │ │ │ │   │ │   │ │   │ ┌►┌─┌─ в            case
# │ │ │ │ │ │ │ │ │ │   │ │   │ │   │ │ │ └► отличие      fixed
# │ │ │ │ │ │ │ │ │ │   │ │   │ │   │ │ └──► от           fixed
# │ │ │ │ │ │ │ │ │ │   │ │   │ │   │ │   ┌► американских amod
# │ │ │ │ │ │ │ │ └─│   │ └──►└─│ ┌─└─└───└─ цен          obl
# │ │ │ │ │ │ │ │   │   │       └►│          .            punct
# │ │ │ │ │ │ │ │   │   └────────►│          \            punct
# │ │ │ │ │ │ │ │   │             │     ┌──► n            punct
# │ │ │ │ │ │ │ │   │             │     │ ┌► Напомним     appos
# │ │ │ │ │ │ │ │   │             └────►│ │  ,            punct
# │ │ │ │ │ │ │ │   │               ┌──►│ │  изначально   advmod
# │ │ │ │ │ │ └─│   │               │ ┌►└─└─ RX           nsubj
# │ │ │ │ │ │   │   │               │ │ │ └► 7700         flat:foreign
# │ │ │ │ │ │   │   │               │ │ └──► XT           flat:foreign
# │ │ │ │ │ │   └──►│             ┌─└─└─┌─── стоила       parataxis
# │ │ │ │ │ │       │             │     │ ┌► 450          nummod
# │ │ │ │ │ │       │             │     └►└─ долларов     obj
# │ │ │ │ │ │       │         ┌──►│          ,            punct
# │ │ │ │ │ │       │         │ ┌►│          а            cc
# │ │ │ │ │ │       │         │ │ │       ┌► первое       amod
# │ │ │ │ │ │       │         │ │ │   ┌──►└─ время        obl
# │ │ │ │ │ │       │         │ │ └──►│      везде        advmod
# │ │ │ │ │ │       └────────►│ │     │      была         cop
# │ │ │ │ │ │                 │ │     │   ┌► даже         advmod
# │ │ │ │ │ │                 │ │     │ ┌►└─ несколько    advmod
# └─│ └►└─└─└─────────────────└─└─────└─└─── дороже       parataxis
#   └──────────────────────────────────────► .            punct
#     ┌──────────► Теперь    advmod
#     │            же
#     │         ┌► при       case
# ┌───│ ┌──►┌───└─ цене      obl
# │   │ │   │ ┌──► в         case
# │   │ │   │ │ ┌► 400       nummod
# │   │ │ ┌─└►└─└─ долларов  nmod
# │ ┌►│ │ │        и         cc
# │ │ │ │ │     ┌► 420       nummod
# │ │ │ │ └────►└─ евро      conj
# │ │ │ │       ┌► этот      det
# │ │ │ │   ┌──►└─ адаптер   nsubj
# │ │ │ │   │   ┌► лишь      advmod
# │ │ │ │   │ ┌►└─ немногим  obl
# │ │ └─└───└─└─┌─ дороже
# │ │ │ ┌─┌─┌─┌─└► RTX       obl
# │ │ │ │ │ │ └──► 4060      appos
# │ │ │ │ │ └────► Ti        flat:foreign
# │ │ │ │ └──────► 8         flat:foreign
# │ │ │ └────────► GB        flat:foreign
# │ │ │       ┌──► и         cc
# │ │ │       │ ┌► несколько advmod
# └►└─│       └─└─ дешевле   conj
#     │     ┌─└►┌─ RTX       obl
#     │     │   └► 4060      appos
#     │     └────► Ti        flat:foreign
#     └──────────► .         punct
#                   ┌► При              case
#   ┌──────────────►└─ этом             obl
#   │   ┌──────────►┌─ адаптер          nsubj
#   │   │           └► AMD              appos
#   │   │           ┌► существенно      advmod
# ┌─│   │ ┌─────┌───└─ производительнее
# │ │   │ │     │ ┌──► и                cc
# │ │   │ │     │ │ ┌► намного          advmod
# │ │ ┌─│ │   ┌─└►└─└─ ближе            conj
# │ │ │ │ │   │ │   ┌► к                case
# │ │ │ │ │   │ └►┌─└─ RTX              obl
# │ │ │ │ │   │   └──► 4070             appos
# │ │ │ │ │ ┌►│        ,                punct
# │ │ │ │ │ │ └──────► а                cc
# │ │ │ │ └►│     ┌─── последняя        nsubj
# │ │ │ │   │     │ ┌► в                case
# │ │ │ │   │     └►└─ Европе           nmod
# │ └─│ └───└───┌───── стоит
# │   │         │ ┌──► от               case
# │   │         │ │ ┌► 540              nummod
# │   │         └►└─└─ евро             obj
# │   │         │ └──► .                punct
# │   │         └────► '                punct
# │   └──────────────► ,                punct
# └──────────────────► )                punct

# %% [markdown]
# <h3>Токенизация

# %%
for sentence in doc.sents:
  for token in sentence.tokens:
    print(token)
# Out:
# DocToken(stop=1, text='(', id='1_1', head_id='1_12', rel='punct', pos='PUNCT')
# DocToken(start=1, stop=2, text="'", id='1_2', head_id='1_3', rel='punct', pos='PUNCT')
# DocToken(start=2, stop=12, text='Видеокарты', id='1_3', head_id='1_12', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Masc,Plur>)
# DocToken(start=13, stop=19, text='Radeon', id='1_4', head_id='1_3', rel='appos', pos='X', feats=<Yes>)
# DocToken(start=20, stop=22, text='RX', id='1_5', head_id='1_4', rel='flat:foreign', pos='X', feats=<Yes>)
# DocToken(start=23, stop=27, text='6000', id='1_6', head_id='1_4', rel='appos', pos='NUM')
# DocToken(start=27, stop=28, text=',', id='1_7', head_id='1_3', rel='punct', pos='PUNCT')
# DocToken(start=29, stop=32, text='как', id='1_8', head_id='1_3', rel='case', pos='SCONJ')
# DocToken(start=33, stop=35, text='мы', id='1_9', head_id='1_12', rel='nsubj', pos='PRON', feats=<Nom,Plur,1>)
# DocToken(start=36, stop=39, text='уже', id='1_10', head_id='1_11', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=40, stop=47, text='сегодня', id='1_11', head_id='1_12', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=48, stop=56, text='говорили', id='1_12', head_id='1_0', rel='root', pos='VERB', feats=<Imp,Ind,Plur,Past,Fin,Act>)
# DocToken(start=56, stop=57, text=',', id='1_13', head_id='1_15', rel='punct', pos='PUNCT')
# DocToken(start=58, stop=68, text='постепенно', id='1_14', head_id='1_15', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=69, stop=77, text='исчезают', id='1_15', head_id='1_12', rel='conj', pos='VERB', feats=<Imp,Ind,Plur,3,Pres,Fin,Act>)
# DocToken(start=78, stop=80, text='из', id='1_16', head_id='1_17', rel='case', pos='ADP')
# DocToken(start=81, stop=88, text='продажи', id='1_17', head_id='1_15', rel='obl', pos='NOUN', feats=<Inan,Gen,Fem,Sing>)
# DocToken(start=88, stop=89, text='.', id='1_18', head_id='1_12', rel='punct', pos='PUNCT')
# DocToken(start=90, stop=93, text='Это', id='2_1', head_id='2_4', rel='nsubj', pos='PRON', feats=<Inan,Nom,Neut,Sing>)
# DocToken(start=94, stop=96, text='не', id='2_2', head_id='2_3', rel='advmod', pos='PART', feats=<Neg>)
# DocToken(start=97, stop=102, text='очень', id='2_3', head_id='2_4', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=103, stop=109, text='хорошо', id='2_4', head_id='2_0', rel='root', pos='ADJ', feats=<Pos,Neut,Sing,Short>)
# DocToken(start=110, stop=113, text='для', id='2_5', head_id='2_6', rel='case', pos='ADP')
# DocToken(start=114, stop=122, text='геймеров', id='2_6', head_id='2_4', rel='obl', pos='NOUN', feats=<Anim,Gen,Masc,Plur>)
# DocToken(start=122, stop=123, text=',', id='2_7', head_id='2_14', rel='punct', pos='PUNCT')
# DocToken(start=124, stop=127, text='так', id='2_8', head_id='2_14', rel='mark', pos='ADV', feats=<Pos>)
# DocToken(start=128, stop=131, text='как', id='2_9', head_id='2_8', rel='fixed', pos='SCONJ')
# DocToken(start=132, stop=139, text='линейка', id='2_10', head_id='2_14', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Fem,Sing>)
# DocToken(start=140, stop=146, text='Radeon', id='2_11', head_id='2_10', rel='appos', pos='X', feats=<Yes>)
# DocToken(start=147, stop=149, text='RX', id='2_12', head_id='2_11', rel='flat:foreign', pos='X', feats=<Yes>)
# DocToken(start=150, stop=154, text='7000', id='2_13', head_id='2_11', rel='appos', pos='NUM')
# DocToken(start=155, stop=163, text='включает', id='2_14', head_id='2_0', rel='root', pos='VERB', feats=<Imp,Ind,Sing,3,Pres,Fin,Act>)
# DocToken(start=164, stop=170, text='меньше', id='2_15', head_id='2_16', rel='nummod:gov', pos='NUM', feats=<Cmp>)
# DocToken(start=171, stop=178, text='моделей', id='2_16', head_id='2_14', rel='obj', pos='NOUN', feats=<Inan,Gen,Fem,Plur>)
# DocToken(start=178, stop=179, text='.', id='2_17', head_id='2_4', rel='punct', pos='PUNCT')
# DocToken(start=180, stop=186, text='Однако', id='3_1', head_id='3_5', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=187, stop=194, text='хорошая', id='3_2', head_id='3_3', rel='amod', pos='ADJ', feats=<Nom,Pos,Fem,Sing>)
# DocToken(start=195, stop=202, text='новость', id='3_3', head_id='3_12', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Fem,Sing>)
# DocToken(start=203, stop=204, text='в', id='3_4', head_id='3_5', rel='case', pos='ADP')
# DocToken(start=205, stop=208, text='том', id='3_5', head_id='3_0', rel='root', pos='PRON', feats=<Inan,Loc,Neut,Sing>)
# DocToken(start=208, stop=209, text=',', id='3_6', head_id='3_12', rel='punct', pos='PUNCT')
# DocToken(start=210, stop=213, text='что', id='3_7', head_id='3_12', rel='mark', pos='SCONJ')
# DocToken(start=214, stop=224, text='видеокарты', id='3_8', head_id='3_12', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Masc,Plur>)
# DocToken(start=225, stop=227, text='RX', id='3_9', head_id='3_8', rel='appos', pos='PROPN', feats=<Yes>)
# DocToken(start=228, stop=232, text='7000', id='3_10', head_id='3_9', rel='appos', pos='NUM')
# DocToken(start=233, stop=240, text='активно', id='3_11', head_id='3_12', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=241, stop=249, text='дешевеют', id='3_12', head_id='3_5', rel='acl', pos='VERB', feats=<Imp,Ind,Plur,3,Pres,Fin,Act>)
# DocToken(start=249, stop=250, text='.', id='3_13', head_id='3_12', rel='punct', pos='PUNCT')
# DocToken(start=251, stop=260, text='Буквально', id='4_1', head_id='4_2', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=261, stop=268, text='недавно', id='4_2', head_id='4_4', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=269, stop=272, text='AMD', id='4_3', head_id='4_4', rel='nsubj', pos='PROPN', feats=<Yes>)
# DocToken(start=273, stop=280, text='снижала', id='4_4', head_id='4_0', rel='root', pos='VERB', feats=<Imp,Fem,Ind,Sing,Past,Fin,Act>)
# DocToken(start=281, stop=285, text='цену', id='4_5', head_id='4_4', rel='obj', pos='NOUN', feats=<Inan,Acc,Fem,Sing>)
# DocToken(start=286, stop=288, text='на', id='4_6', head_id='4_7', rel='case', pos='ADP')
# DocToken(start=289, stop=291, text='RX', id='4_7', head_id='4_5', rel='nmod', pos='PROPN', feats=<Yes>)
# DocToken(start=292, stop=296, text='7700', id='4_8', head_id='4_7', rel='appos', pos='NUM')
# DocToken(start=297, stop=299, text='XT', id='4_9', head_id='4_7', rel='flat:foreign', pos='PROPN', feats=<Yes>)
# DocToken(start=299, stop=300, text=',', id='4_10', head_id='4_16', rel='punct', pos='PUNCT')
# DocToken(start=301, stop=302, text='а', id='4_11', head_id='4_16', rel='cc', pos='CCONJ')
# DocToken(start=303, stop=309, text='сейчас', id='4_12', head_id='4_16', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=310, stop=313, text='эта', id='4_13', head_id='4_14', rel='det', pos='DET', feats=<Nom,Fem,Sing>)
# DocToken(start=314, stop=319, text='карта', id='4_14', head_id='4_16', rel='nsubj:pass', pos='NOUN', feats=<Inan,Nom,Fem,Sing>)
# DocToken(start=320, stop=323, text='уже', id='4_15', head_id='4_16', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=324, stop=333, text='продаётся', id='4_16', head_id='4_23', rel='conj', pos='VERB', feats=<Imp,Ind,Sing,3,Pres,Fin,Pass>)
# DocToken(start=334, stop=341, text='дешевле', id='4_17', head_id='4_16', rel='advmod', pos='ADV', feats=<Cmp>)
# DocToken(start=341, stop=342, text='.', id='4_18', head_id='4_16', rel='punct', pos='PUNCT')
# DocToken(start=342, stop=343, text='\\', id='4_19', head_id='4_21', rel='punct', pos='X', feats=<Yes>)
# DocToken(start=343, stop=344, text='n', id='4_20', head_id='4_7', rel='punct', pos='NOUN')
# DocToken(start=344, stop=354, text='Официально', id='4_21', head_id='4_16', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=355, stop=359, text='цена', id='4_22', head_id='4_23', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Fem,Sing>)
# DocToken(start=360, stop=365, text='упала', id='4_23', head_id='4_0', rel='root', pos='VERB', feats=<Perf,Fem,Ind,Sing,Past,Fin,Act>)
# DocToken(start=366, stop=368, text='до', id='4_24', head_id='4_26', rel='case', pos='ADP')
# DocToken(start=369, stop=372, text='420', id='4_25', head_id='4_26', rel='nummod', pos='NUM')
# DocToken(start=373, stop=381, text='долларов', id='4_26', head_id='4_23', rel='obl', pos='NOUN', feats=<Inan,Gen,Masc,Plur>)
# DocToken(start=382, stop=383, text='в', id='4_27', head_id='4_28', rel='case', pos='ADP')
# DocToken(start=384, stop=391, text='феврале', id='4_28', head_id='4_16', rel='obl', pos='NOUN', feats=<Inan,Loc,Masc,Sing>)
# DocToken(start=391, stop=392, text='.', id='4_29', head_id='4_4', rel='punct', pos='PUNCT')
# DocToken(start=393, stop=399, text='Теперь', id='5_1', head_id='5_7', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=400, stop=402, text='же', id='5_2', head_id='5_1', rel='advmod', pos='PART')
# DocToken(start=403, stop=409, text='многие', id='5_3', head_id='5_4', rel='amod', pos='ADJ', feats=<Nom,Pos,Plur>)
# DocToken(start=410, stop=418, text='продавцы', id='5_4', head_id='5_7', rel='nsubj', pos='NOUN', feats=<Anim,Nom,Masc,Plur>)
# DocToken(start=419, stop=420, text='в', id='5_5', head_id='5_6', rel='case', pos='ADP')
# DocToken(start=421, stop=424, text='США', id='5_6', head_id='5_4', rel='nmod', pos='PROPN', feats=<Inan,Loc,Masc,Plur>)
# DocToken(start=425, stop=435, text='предлагают', id='5_7', head_id='5_0', rel='root', pos='VERB', feats=<Imp,Ind,Plur,3,Pres,Fin,Act>)
# DocToken(start=436, stop=441, text='карту', id='5_8', head_id='5_7', rel='obj', pos='NOUN', feats=<Inan,Acc,Fem,Sing>)
# DocToken(start=442, stop=444, text='по', id='5_9', head_id='5_10', rel='case', pos='ADP')
# DocToken(start=445, stop=449, text='цене', id='5_10', head_id='5_8', rel='nmod', pos='NOUN', feats=<Inan,Dat,Fem,Sing>)
# DocToken(start=450, stop=451, text='в', id='5_11', head_id='5_13', rel='case', pos='ADP')
# DocToken(start=452, stop=455, text='400', id='5_12', head_id='5_13', rel='nummod', pos='NUM')
# DocToken(start=456, stop=464, text='долларов', id='5_13', head_id='5_10', rel='nmod', pos='NOUN', feats=<Inan,Gen,Masc,Plur>)
# DocToken(start=464, stop=465, text=',', id='5_14', head_id='5_19', rel='punct', pos='PUNCT')
# DocToken(start=466, stop=467, text='и', id='5_15', head_id='5_19', rel='cc', pos='CCONJ')
# DocToken(start=468, stop=471, text='это', id='5_16', head_id='5_19', rel='nsubj', pos='PRON', feats=<Inan,Nom,Neut,Sing>)
# DocToken(start=472, stop=475, text='без', id='5_17', head_id='5_19', rel='case', pos='ADP')
# DocToken(start=476, stop=482, text='всяких', id='5_18', head_id='5_19', rel='det', pos='DET', feats=<Gen,Plur>)
# DocToken(start=483, stop=488, text='акций', id='5_19', head_id='5_7', rel='obl', pos='NOUN', feats=<Inan,Gen,Fem,Plur>)
# DocToken(start=488, stop=489, text='.', id='5_20', head_id='5_7', rel='punct', pos='PUNCT')
# DocToken(start=490, stop=491, text='А', id='6_1', head_id='6_14', rel='cc', pos='PROPN')
# DocToken(start=492, stop=496, text='есть', id='6_2', head_id='6_0', rel='root', pos='VERB', feats=<Imp,Ind,Sing,3,Pres,Fin,Act>)
# DocToken(start=497, stop=508, text='предложение', id='6_3', head_id='6_14', rel='nsubj:pass', pos='NOUN', feats=<Inan,Nom,Neut,Sing>)
# DocToken(start=509, stop=510, text='и', id='6_4', head_id='6_7', rel='advmod', pos='PART')
# DocToken(start=511, stop=513, text='за', id='6_5', head_id='6_33', rel='case', pos='ADP')
# DocToken(start=514, stop=517, text='395', id='6_6', head_id='6_7', rel='nummod', pos='NUM')
# DocToken(start=518, stop=526, text='долларов', id='6_7', head_id='6_26', rel='conj', pos='NOUN', feats=<Inan,Gen,Masc,Plur>)
# DocToken(start=526, stop=527, text='.', id='6_8', head_id='6_54', rel='punct', pos='PUNCT')
# DocToken(start=527, stop=528, text='\\', id='6_9', head_id='6_17', rel='punct', pos='X', feats=<Yes>)
# DocToken(start=528, stop=529, text='n', id='6_10', head_id='6_40', rel='appos', pos='X', feats=<Yes>)
# DocToken(start=529, stop=530, text='В', id='6_11', head_id='6_12', rel='case', pos='ADP')
# DocToken(start=531, stop=537, text='Европе', id='6_12', head_id='6_14', rel='obl', pos='PROPN', feats=<Inan,Loc,Fem,Sing>)
# DocToken(start=538, stop=546, text='ситуация', id='6_13', head_id='6_14', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Fem,Sing>)
# DocToken(start=547, stop=553, text='схожая', id='6_14', head_id='6_0', rel='root', pos='ADJ', feats=<Nom,Pos,Fem,Sing>)
# DocToken(start=553, stop=554, text=':', id='6_15', head_id='6_17', rel='punct', pos='PUNCT')
# DocToken(start=555, stop=560, text='карта', id='6_16', head_id='6_17', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Fem,Sing>)
# DocToken(start=561, stop=569, text='стартует', id='6_17', head_id='6_14', rel='parataxis', pos='VERB', feats=<Perf,Ind,Sing,3,Fut,Fin,Act>)
# DocToken(start=570, stop=571, text='с', id='6_18', head_id='6_20', rel='case', pos='ADP')
# DocToken(start=572, stop=575, text='420', id='6_19', head_id='6_20', rel='nummod', pos='NUM')
# DocToken(start=576, stop=580, text='евро', id='6_20', head_id='6_17', rel='obl', pos='NOUN', feats=<Inan,Gen,Masc,Plur>)
# DocToken(start=580, stop=581, text=',', id='6_21', head_id='6_54', rel='punct', pos='PUNCT')
# DocToken(start=582, stop=584, text='но', id='6_22', head_id='6_54', rel='cc', pos='CCONJ')
# DocToken(start=585, stop=588, text='это', id='6_23', head_id='6_54', rel='nsubj', pos='PRON', feats=<Inan,Nom,Neut,Sing>)
# DocToken(start=589, stop=592, text='уже', id='6_24', head_id='6_33', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=593, stop=594, text='с', id='6_25', head_id='6_26', rel='case', pos='ADP')
# DocToken(start=595, stop=601, text='учётом', id='6_26', head_id='6_14', rel='parataxis', pos='NOUN', feats=<Inan,Ins,Fem,Sing>)
# DocToken(start=602, stop=609, text='налогов', id='6_27', head_id='6_26', rel='nmod', pos='NOUN', feats=<Inan,Gen,Masc,Plur>)
# DocToken(start=609, stop=610, text=',', id='6_28', head_id='6_33', rel='punct', pos='PUNCT')
# DocToken(start=611, stop=612, text='в', id='6_29', head_id='6_33', rel='case', pos='ADP')
# DocToken(start=613, stop=620, text='отличие', id='6_30', head_id='6_29', rel='fixed', pos='NOUN', feats=<Inan,Acc,Neut,Sing>)
# DocToken(start=621, stop=623, text='от', id='6_31', head_id='6_29', rel='fixed', pos='ADP')
# DocToken(start=624, stop=636, text='американских', id='6_32', head_id='6_33', rel='amod', pos='ADJ', feats=<Gen,Pos,Plur>)
# DocToken(start=637, stop=640, text='цен', id='6_33', head_id='6_17', rel='obl', pos='NOUN', feats=<Inan,Gen,Fem,Plur>)
# DocToken(start=640, stop=641, text='.', id='6_34', head_id='6_26', rel='punct', pos='PUNCT')
# DocToken(start=641, stop=642, text='\\', id='6_35', head_id='6_17', rel='punct', pos='PUNCT')
# DocToken(start=642, stop=643, text='n', id='6_36', head_id='6_40', rel='punct', pos='X', feats=<Yes>)
# DocToken(start=643, stop=651, text='Напомним', id='6_37', head_id='6_40', rel='appos', pos='VERB', feats=<Perf,Ind,Plur,1,Fut,Fin,Act>)
# DocToken(start=651, stop=652, text=',', id='6_38', head_id='6_33', rel='punct', pos='PUNCT')
# DocToken(start=653, stop=663, text='изначально', id='6_39', head_id='6_43', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=664, stop=666, text='RX', id='6_40', head_id='6_43', rel='nsubj', pos='PROPN', feats=<Yes>)
# DocToken(start=667, stop=671, text='7700', id='6_41', head_id='6_40', rel='flat:foreign', pos='NUM')
# DocToken(start=672, stop=674, text='XT', id='6_42', head_id='6_40', rel='flat:foreign', pos='PROPN', feats=<Yes>)
# DocToken(start=675, stop=681, text='стоила', id='6_43', head_id='6_14', rel='parataxis', pos='VERB', feats=<Imp,Fem,Ind,Sing,Past,Fin,Act>)
# DocToken(start=682, stop=685, text='450', id='6_44', head_id='6_45', rel='nummod', pos='NUM')
# DocToken(start=686, stop=694, text='долларов', id='6_45', head_id='6_43', rel='obj', pos='NOUN', feats=<Inan,Gen,Masc,Plur>)
# DocToken(start=694, stop=695, text=',', id='6_46', head_id='6_54', rel='punct', pos='PUNCT')
# DocToken(start=696, stop=697, text='а', id='6_47', head_id='6_54', rel='cc', pos='CCONJ')
# DocToken(start=698, stop=704, text='первое', id='6_48', head_id='6_49', rel='amod', pos='ADJ', feats=<Nom,Pos,Neut,Sing>)
# DocToken(start=705, stop=710, text='время', id='6_49', head_id='6_54', rel='obl', pos='NOUN', feats=<Inan,Nom,Neut,Sing>)
# DocToken(start=711, stop=716, text='везде', id='6_50', head_id='6_43', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=717, stop=721, text='была', id='6_51', head_id='6_26', rel='cop', pos='AUX', feats=<Imp,Fem,Ind,Sing,Past,Fin,Act>)
# DocToken(start=722, stop=726, text='даже', id='6_52', head_id='6_53', rel='advmod', pos='PART')
# DocToken(start=727, stop=736, text='несколько', id='6_53', head_id='6_54', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=737, stop=743, text='дороже', id='6_54', head_id='6_14', rel='parataxis', pos='ADJ', feats=<Cmp>)
# DocToken(start=743, stop=744, text='.', id='6_55', head_id='6_14', rel='punct', pos='PUNCT')
# DocToken(start=745, stop=751, text='Теперь', id='7_1', head_id='7_15', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=752, stop=754, text='же', id='7_2', head_id='7_1', rel='advmod', pos='PART')
# DocToken(start=755, stop=758, text='при', id='7_3', head_id='7_4', rel='case', pos='ADP')
# DocToken(start=759, stop=763, text='цене', id='7_4', head_id='7_15', rel='obl', pos='NOUN', feats=<Inan,Loc,Fem,Sing>)
# DocToken(start=764, stop=765, text='в', id='7_5', head_id='7_7', rel='case', pos='ADP')
# DocToken(start=766, stop=769, text='400', id='7_6', head_id='7_7', rel='nummod', pos='NUM')
# DocToken(start=770, stop=778, text='долларов', id='7_7', head_id='7_4', rel='nmod', pos='NOUN', feats=<Inan,Gen,Masc,Plur>)
# DocToken(start=779, stop=780, text='и', id='7_8', head_id='7_23', rel='cc', pos='CCONJ')
# DocToken(start=781, stop=784, text='420', id='7_9', head_id='7_10', rel='nummod', pos='NUM')
# DocToken(start=785, stop=789, text='евро', id='7_10', head_id='7_7', rel='conj', pos='NOUN', feats=<Inan,Gen,Masc,Sing>)
# DocToken(start=790, stop=794, text='этот', id='7_11', head_id='7_12', rel='det', pos='DET', feats=<Nom,Masc,Sing>)
# DocToken(start=795, stop=802, text='адаптер', id='7_12', head_id='7_15', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Masc,Sing>)
# DocToken(start=803, stop=807, text='лишь', id='7_13', head_id='7_14', rel='advmod', pos='PART')
# DocToken(start=808, stop=816, text='немногим', id='7_14', head_id='7_15', rel='obl', pos='NOUN', feats=<Inan,Ins,Neut,Sing>)
# DocToken(start=817, stop=823, text='дороже', id='7_15', head_id='7_0', rel='root', pos='ADV', feats=<Cmp>)
# DocToken(start=824, stop=827, text='RTX', id='7_16', head_id='7_15', rel='obl', pos='PROPN', feats=<Yes>)
# DocToken(start=828, stop=832, text='4060', id='7_17', head_id='7_16', rel='appos', pos='NUM')
# DocToken(start=833, stop=835, text='Ti', id='7_18', head_id='7_16', rel='flat:foreign', pos='X', feats=<Yes>)
# DocToken(start=836, stop=837, text='8', id='7_19', head_id='7_16', rel='flat:foreign', pos='NUM')
# DocToken(start=837, stop=839, text='GB', id='7_20', head_id='7_16', rel='flat:foreign', pos='PROPN', feats=<Yes>)
# DocToken(start=840, stop=841, text='и', id='7_21', head_id='7_23', rel='cc', pos='CCONJ')
# DocToken(start=842, stop=851, text='несколько', id='7_22', head_id='7_23', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=852, stop=859, text='дешевле', id='7_23', head_id='7_4', rel='conj', pos='ADV', feats=<Cmp>)
# DocToken(start=860, stop=863, text='RTX', id='7_24', head_id='7_23', rel='obl', pos='PROPN', feats=<Yes>)
# DocToken(start=864, stop=868, text='4060', id='7_25', head_id='7_24', rel='appos', pos='NUM')
# DocToken(start=869, stop=871, text='Ti', id='7_26', head_id='7_24', rel='flat:foreign', pos='X', feats=<Yes>)
# DocToken(start=871, stop=872, text='.', id='7_27', head_id='7_15', rel='punct', pos='PUNCT')
# DocToken(start=873, stop=876, text='При', id='8_1', head_id='8_2', rel='case', pos='ADP')
# DocToken(start=877, stop=881, text='этом', id='8_2', head_id='8_18', rel='obl', pos='PRON', feats=<Inan,Loc,Neut,Sing>)
# DocToken(start=882, stop=889, text='адаптер', id='8_3', head_id='8_18', rel='nsubj', pos='NOUN', feats=<Inan,Nom,Masc,Sing>)
# DocToken(start=890, stop=893, text='AMD', id='8_4', head_id='8_3', rel='appos', pos='PROPN', feats=<Yes>)
# DocToken(start=894, stop=905, text='существенно', id='8_5', head_id='8_6', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=906, stop=922, text='производительнее', id='8_6', head_id='8_0', rel='root', pos='ADJ', feats=<Cmp>)
# DocToken(start=923, stop=924, text='и', id='8_7', head_id='8_9', rel='cc', pos='CCONJ')
# DocToken(start=925, stop=932, text='намного', id='8_8', head_id='8_9', rel='advmod', pos='ADV', feats=<Pos>)
# DocToken(start=933, stop=938, text='ближе', id='8_9', head_id='8_6', rel='conj', pos='ADV', feats=<Cmp>)
# DocToken(start=939, stop=940, text='к', id='8_10', head_id='8_11', rel='case', pos='ADP')
# DocToken(start=941, stop=944, text='RTX', id='8_11', head_id='8_9', rel='obl', pos='PROPN', feats=<Yes>)
# DocToken(start=945, stop=949, text='4070', id='8_12', head_id='8_11', rel='appos', pos='NUM')
# DocToken(start=949, stop=950, text=',', id='8_13', head_id='8_18', rel='punct', pos='PUNCT')
# DocToken(start=951, stop=952, text='а', id='8_14', head_id='8_9', rel='cc', pos='CCONJ')
# DocToken(start=953, stop=962, text='последняя', id='8_15', head_id='8_6', rel='nsubj', pos='ADJ', feats=<Nom,Pos,Fem,Sing>)
# DocToken(start=963, stop=964, text='в', id='8_16', head_id='8_17', rel='case', pos='ADP')
# DocToken(start=965, stop=971, text='Европе', id='8_17', head_id='8_15', rel='nmod', pos='PROPN', feats=<Inan,Loc,Fem,Sing>)
# DocToken(start=972, stop=977, text='стоит', id='8_18', head_id='8_0', rel='root', pos='VERB', feats=<Imp,Ind,Sing,3,Pres,Fin,Act>)
# DocToken(start=978, stop=980, text='от', id='8_19', head_id='8_21', rel='case', pos='ADP')
# DocToken(start=981, stop=984, text='540', id='8_20', head_id='8_21', rel='nummod', pos='NUM')
# DocToken(start=985, stop=989, text='евро', id='8_21', head_id='8_18', rel='obj', pos='NOUN', feats=<Inan,Gen,Masc,Plur>)
# DocToken(start=989, stop=990, text='.', id='8_22', head_id='8_21', rel='punct', pos='PUNCT')
# DocToken(start=990, stop=991, text="'", id='8_23', head_id='8_21', rel='punct', pos='PUNCT')
# DocToken(start=991, stop=992, text=',', id='8_24', head_id='8_9', rel='punct', pos='PUNCT')
# DocToken(start=992, stop=993, text=')', id='8_25', head_id='8_6', rel='punct', pos='PUNCT')

# %% [markdown]
# <h3>Лемматизация

# %%
# Заменяем слова на их леммы (начальные формы слова)
for sentence in doc.sents:
  for token in sentence.tokens:
    token.lemmatize(morph_vocab)
  lemmas = {_.text: _.lemma for _ in sentence.tokens}
  print(lemmas.items())
# Out:
# dict_items([('(', '('), ("'", "'"), ('Видеокарты', 'видеокарта'), ('Radeon', 'radeon'), ('RX', 'rx'), ('6000', '6000'), (',', ','), ('как', 'как'), ('мы', 'мы'), ('уже', 'уже'), ('сегодня', 'сегодня'), ('говорили', 'говорить'), ('постепенно', 'постепенно'), ('исчезают', 'исчезать'), ('из', 'из'), ('продажи', 'продажа'), ('.', '.')])
# dict_items([('Это', 'это'), ('не', 'не'), ('очень', 'очень'), ('хорошо', 'хороший'), ('для', 'для'), ('геймеров', 'геймер'), (',', ','), ('так', 'так'), ('как', 'как'), ('линейка', 'линейка'), ('Radeon', 'radeon'), ('RX', 'rx'), ('7000', '7000'), ('включает', 'включать'), ('меньше', 'меньше'), ('моделей', 'модель'), ('.', '.')])
# dict_items([('Однако', 'однако'), ('хорошая', 'хороший'), ('новость', 'новость'), ('в', 'в'), ('том', 'тот'), (',', ','), ('что', 'что'), ('видеокарты', 'видеокарта'), ('RX', 'rx'), ('7000', '7000'), ('активно', 'активно'), ('дешевеют', 'дешеветь'), ('.', '.')])
# dict_items([('Буквально', 'буквально'), ('недавно', 'недавно'), ('AMD', 'amd'), ('снижала', 'снижать'), ('цену', 'цена'), ('на', 'на'), ('RX', 'rx'), ('7700', '7700'), ('XT', 'xt'), (',', ','), ('а', 'а'), ('сейчас', 'сейчас'), ('эта', 'этот'), ('карта', 'карта'), ('уже', 'уже'), ('продаётся', 'продаваться'), ('дешевле', 'дешевый'), ('.', '.'), ('\\', '\\'), ('n', 'n'), ('Официально', 'официально'), ('цена', 'цена'), ('упала', 'упасть'), ('до', 'до'), ('420', '420'), ('долларов', 'доллар'), ('в', 'в'), ('феврале', 'февраль')])
# dict_items([('Теперь', 'теперь'), ('же', 'же'), ('многие', 'многий'), ('продавцы', 'продавец'), ('в', 'в'), ('США', 'сша'), ('предлагают', 'предлагать'), ('карту', 'карта'), ('по', 'по'), ('цене', 'цена'), ('400', '400'), ('долларов', 'доллар'), (',', ','), ('и', 'и'), ('это', 'это'), ('без', 'без'), ('всяких', 'всякий'), ('акций', 'акция'), ('.', '.')])
# dict_items([('А', 'а'), ('есть', 'быть'), ('предложение', 'предложение'), ('и', 'и'), ('за', 'за'), ('395', '395'), ('долларов', 'доллар'), ('.', '.'), ('\\', '\\'), ('n', 'n'), ('В', 'в'), ('Европе', 'европа'), ('ситуация', 'ситуация'), ('схожая', 'схожий'), (':', ':'), ('карта', 'карта'), ('стартует', 'стартовать'), ('с', 'с'), ('420', '420'), ('евро', 'евро'), (',', ','), ('но', 'но'), ('это', 'это'), ('уже', 'уже'), ('учётом', 'учет'), ('налогов', 'налог'), ('в', 'в'), ('отличие', 'отличие'), ('от', 'от'), ('американских', 'американский'), ('цен', 'цена'), ('Напомним', 'напомнить'), ('изначально', 'изначально'), ('RX', 'rx'), ('7700', '7700'), ('XT', 'xt'), ('стоила', 'стоить'), ('450', '450'), ('а', 'а'), ('первое', 'первый'), ('время', 'время'), ('везде', 'везде'), ('была', 'быть'), ('даже', 'даже'), ('несколько', 'несколько'), ('дороже', 'дороже')])
# dict_items([('Теперь', 'теперь'), ('же', 'же'), ('при', 'при'), ('цене', 'цена'), ('в', 'в'), ('400', '400'), ('долларов', 'доллар'), ('и', 'и'), ('420', '420'), ('евро', 'евро'), ('этот', 'этот'), ('адаптер', 'адаптер'), ('лишь', 'лишь'), ('немногим', 'немногое'), ('дороже', 'дорогой'), ('RTX', 'rtx'), ('4060', '4060'), ('Ti', 'ti'), ('8', '8'), ('GB', 'gb'), ('несколько', 'несколько'), ('дешевле', 'дешевый'), ('.', '.')])
# dict_items([('При', 'при'), ('этом', 'это'), ('адаптер', 'адаптер'), ('AMD', 'amd'), ('существенно', 'существенно'), ('производительнее', 'производительнее'), ('и', 'и'), ('намного', 'намного'), ('ближе', 'близкий'), ('к', 'к'), ('RTX', 'rtx'), ('4070', '4070'), (',', ','), ('а', 'а'), ('последняя', 'последний'), ('в', 'в'), ('Европе', 'европа'), ('стоит', 'стоить'), ('от', 'от'), ('540', '540'), ('евро', 'евро'), ('.', '.'), ("'", "'"), (')', ')')])

# %% [markdown]
# <h2>2. Посчитать наиболее встречающиеся пары подлежащих и сказуемых

# %% [markdown]
# <h3> Пары для одной статьи

# %%
pairs_of_nsubj_and_root = []
for sentence in doc.sents:
    nsubj = root = ''
    for token in sentence.tokens:
        token.lemmatize(morph_vocab)
        if token.rel in {"nsubj", "root"}:
            if token.rel == "nsubj":
                nsubj = token.lemma
            elif token.rel == "root":
                root = token.lemma
            if nsubj and root:
                pairs_of_nsubj_and_root.append((nsubj, root))

print(pairs_of_nsubj_and_root)
# Out:
# [('мы', 'говорить'), ('это', 'хороший'), ('линейка', 'хороший'), ('линейка', 'включать'), ('новость', 'тот'), ('видеокарта', 'тот'), ('amd', 'снижать'), ('цена', 'снижать'), ('цена', 'упасть'), ('продавец', 'предлагать'), ('это', 'предлагать'), ('ситуация', 'быть'), ('ситуация', 'схожий'), ('карта', 'схожий'), ('это', 'схожий'), ('rx', 'схожий'), ('адаптер', 'дорогой'), ('адаптер', 'производительнее'), ('последний', 'производительнее'), ('последний', 'стоить')]

# %% [markdown]
# <h3> Пары для всех статей

# %%
all_pairs_of_nsubj_and_root = []
for article in articles:
  doc = Doc(str(article))
  doc.segment(segmenter)
  doc.parse_syntax(syntax_parser)
  doc.tag_morph(morph_tagger)
  for sentence in doc.sents:
    nsubj = root = ''
    for token in sentence.tokens:
      token.lemmatize(morph_vocab)
      if token.rel == "nsubj":
        nsubj = token.lemma
      if token.rel == 'root':
        root = token.lemma
      if nsubj and root:
        all_pairs_of_nsubj_and_root.append((nsubj, root))

print(all_pairs_of_nsubj_and_root)
# Out:
# [('мы', 'говорить'), ('мы', 'говорить'), ('мы', 'говорить'), ('мы', 'говорить'), ('мы', 'говорить'), ('мы', 'говорить'), ('мы', 'говорить'), ('это', 'хороший'), ('это', 'хороший'), ('это', 'хороший'), ('это', 'хороший'), ('это', 'хороший'), ('это', 'хороший'), ('линейка', 'хороший'), ('линейка', 'хороший'), ('линейка', 'хороший'), ('линейка', 'хороший'), ('линейка', 'включать'), ('линейка', 'включать'), ('линейка', 'включать'), ('линейка', 'включать'), ('новость', 'тот'), ('новость', 'тот'), ('новость', 'тот'), ('видеокарта', 'тот'), ('видеокарта', 'тот'), ('видеокарта', 'тот'), ('видеокарта', 'тот'), ('видеокарта', 'тот'), ('видеокарта', 'тот'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('amd', 'снижать'), ('цена', 'снижать'), ('цена', 'упасть'), ('цена', 'упасть'), ('цена', 'упасть'), ('цена', 'упасть'), ('цена', 'упасть'), ('цена', 'упасть'), ('цена', 'упасть'), ('продавец', 'предлагать'), ('продавец', 'предлагать'), ('продавец', 'предлагать'), ('продавец', 'предлагать'), ('продавец', 'предлагать'), ('продавец', 'предлагать'), ('продавец', 'предлагать'), ('продавец', 'предлагать'), ('продавец', 'предлагать'), ('это', 'предлагать'), ('это', 'предлагать'), ('это', 'предлагать'), ('это', 'предлагать'), ('это', 'предлагать'), ('ситуация', 'быть'), ('ситуация', 'схожий'), ('ситуация', 'схожий'), ('карта', 'схожий'), ('карта', 'схожий'), ('карта', 'схожий'), ('карта', 'схожий'), ('карта', 'схожий'), ('карта', 'схожий'), ('карта', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('это', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('rx', 'схожий'), ('адаптер', 'дорогой'), ('адаптер', 'дорогой'), ('адаптер', 'дорогой'), ('адаптер', 'дорогой'), ('адаптер', 'дорогой'), ('адаптер', 'дорогой'), ('адаптер', 'дорогой'), ('адаптер', 'дорогой'), ('адаптер', 'дорогой'), ('адаптер', 'дорогой'), ('адаптер', 'дорогой'), ('адаптер', 'дорогой'), ('адаптер', 'дорогой'), ('адаптер', 'производительнее'), ('адаптер', 'производительнее'), ('адаптер', 'производительнее'), ('адаптер', 'производительнее'), ('адаптер', 'производительнее'), ('адаптер', 'производительнее'), ('адаптер', 'производительнее'), ('адаптер', 'производительнее'), ('адаптер', 'производительнее'), ('последний', 'производительнее'), ('последний', 'производительнее'), ('последний', 'производительнее'), ('последний', 'стоить'), ('последний', 'стоить'), ('последний', 'стоить'), ('последний', 'стоить'), ('последний', 'стоить'), ('последний', 'стоить'), ('последний', 'стоить'), ('последний', 'стоить'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('видеокарта', 'оставаться'), ('адаптер', 'начать'), ('адаптер', 'начать'), ('адаптер', 'начать'), ('адаптер', 'начать'), ('адаптер', 'начать'), ('адаптер', 'начать'), ('адаптер', 'начать'), ('адаптер', 'начать'), ('адаптер', 'начать') ...

# %% [markdown]
# <h3> Наиболее встречающиеся фразы

# %%
all_pairs_counter = Counter(all_pairs_of_nsubj_and_root)
all_pairs_counter.most_common(20) # используется метод объекта Counter
# Out:
# [(('который', 'представить'), 113),
#  (('мы', 'отмечать'), 68),
#  (('рост', 'связать'), 56),
#  (('что', 'выявить'), 54),
#  (('смартфон', 'опираться'), 53),
#  (('это', 'больше'), 51),
#  (('машина', 'продаваться'), 51),
#  (('они', 'иметь'), 49),
#  (('это', 'заявлять'), 49),
#  (('версия', 'оснащать'), 48),
#  (('команды-участник', 'смочь'), 47),
#  (('достижение', 'являться'), 46),
#  (('менеджер', 'подписать'), 46),
#  (('он', 'мочь'), 45),
#  (('речь', 'идти'), 43),
#  (('команда', 'объявить'), 43),
#  (('аппарат', 'готовый'), 43),
#  (('они', 'провести'), 41),
#  (('россиянин', 'потратить'), 41),
#  (('этап', 'отмечать'), 40)]

# %% [markdown]
# <h2> 3. Самые популярные слова (без стоп-слов, цифр и знаков пунктуации)

# %%
popular_words = []
delete_punctuation = set(string.punctuation + '«»—' + string.digits + 'n')
stop_words = set(stopwords.words('russian'))
for article in articles:
  doc = Doc(str(article))
  doc.segment(segmenter)
  doc.parse_syntax(syntax_parser)
  doc.tag_morph(morph_tagger)
  for sentence in doc.sents:
    for token in sentence.tokens:
      token.lemmatize(morph_vocab)
      if token.lemma not in delete_punctuation and token.lemma not in stop_words:
        popular_words.append(token.lemma)

filtered_count = Counter(popular_words)
filtered_count.most_common(20)
# Out:
# [('xa', 133),
#  ('год', 131),
#  ('новый', 104),
#  ('это', 95),
#  ('который', 84),
#  ('компания', 58),
#  ('автомобиль', 53),
#  ('рубль', 53),
#  ('свой', 51),
#  ('весь', 50),
#  ('также', 48),
#  ('цена', 47),
#  ('машина', 44),
#  ('млн', 44),
#  ('первый', 42),
#  ('мочь', 36),
#  ('доллар', 35),
#  ('рынок', 34),
#  ('получить', 34),
#  ('заявить', 32)]

# %% [markdown]
# Топ 5 популярных слов: ха, год, новый, это, который

# %% [markdown]
# <h2>4. Статистика

# %% [markdown]
# <h3>По встречающимся парам "подлежащее + сказуемое" в статьях

# %%
pairs = [pair[0][0] + ' ' + pair[0][1] for pair in all_pairs_counter.most_common(12)]
counter = [pair[1] for pair in all_pairs_counter.most_common(12)]

plt.figure(figsize=(20, 5))
plt.bar(pairs, counter, color = 'blue')
plt.title("Наиболее встречающеся пары")
plt.ylabel("Количество")
plt.xlabel("Пара подлежащее + сказуемое")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>По словам

# %%
words = [pair[0] for pair in filtered_count.most_common(20)]
counter = [pair[1] for pair in filtered_count.most_common(20)]

plt.figure(figsize=(18, 6))
plt.bar(words, counter, color = 'blue')
plt.title("Самые популярные слова за исключением стоп-слов")
plt.ylabel("Количество")
plt.xlabel("Слово")
plt.tight_layout()
plt.show()
